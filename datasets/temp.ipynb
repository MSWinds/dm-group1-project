# %%
with open('disabled.pl', 'r') as file: # read the pl file
    disabled_data = file.read()

# %%
print(disabled_data) # 1 if the corresponding StudentId is in the Disabled file; 0 otherwise
# Out:
# disabled(student992).
# disabled(student976).
# disabled(student963).
# disabled(student918).
# disabled(student913).
# disabled(student909).
# disabled(student885).
# disabled(student881).
# disabled(student870).
# disabled(student852).
# disabled(student838).
# disabled(student831).
# disabled(student830).
# disabled(student823).
# disabled(student805).
# disabled(student770).
# disabled(student762).
# disabled(student748).
# disabled(student738).
# disabled(student734).
# disabled(student733).
# disabled(student732).
# disabled(student700).
# disabled(student698).
# disabled(student680).
# disabled(student673).
# disabled(student663).
# disabled(student659).
# disabled(student650).
# disabled(student634).
# disabled(student628).
# disabled(student602).
# disabled(student600).
# disabled(student598).
# disabled(student594).
# disabled(student580).
# disabled(student565).
# disabled(student560).
# disabled(student559).
# disabled(student512).
# disabled(student505).
# ...
